# %%
# !pip install pyreadr
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.4/252.4 kB 2.5 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import pyreadr

protein_domains_rds = '/Users/haochen/Desktop/software/maftools/inst/extdata/protein_domains.RDs'

prot_df = pyreadr.read_r(protein_domains_rds)[None] # also works for RData

# %%
prot_df.loc[prot_df['HGNC']=='TP53']
# Out:
#        HGNC     refseq.ID    protein.ID  aa.length  Start    End  \
# 75409  TP53     NM_000546     NP_000537      393.0    5.0   29.0
# 75410  TP53     NM_000546     NP_000537      393.0  109.0  288.0
# 75411  TP53     NM_000546     NP_000537      393.0  319.0  359.0
# 75412  TP53  NM_001126112  NP_001119584      393.0    5.0   29.0
# 75413  TP53  NM_001126112  NP_001119584      393.0  109.0  288.0
# 75414  TP53  NM_001126112  NP_001119584      393.0  319.0  359.0
# 75415  TP53  NM_001126113  NP_001119585      346.0    5.0   29.0
# 75416  TP53  NM_001126113  NP_001119585      346.0  109.0  288.0
# 75417  TP53  NM_001126114  NP_001119586      341.0    5.0   29.0
# 75418  TP53  NM_001126114  NP_001119586      341.0  109.0  288.0
# 75419  TP53  NM_001126115  NP_001119587      261.0    1.0  156.0
# 75420  TP53  NM_001126115  NP_001119587      261.0  187.0  227.0
# 75421  TP53  NM_001126116  NP_001119588      209.0    1.0  156.0
# ...
